# %%
import numpy as np
from bqplot import pyplot as plt
np.random.seed(0)
n = 200
X = np.linspace(0.0, 10.0, n)
numbers = np.random.rand(n)

f = plt.figure()
plt.plot(X, numbers)
plt.show()
# Out:
# VBox(children=(Figure(axes=[Axis(scale=LinearScale()), Axis(orientation='vertical', scale=LinearScale())], fig…

# %%
import pandas as pd
import sqlalchemy as sql
import datetime

# read password and user to database
credentials_file = r'../credentials.pw'

credentials = pd.read_csv(credentials_file, header=0)
user = credentials['username'].values[0]
pw = credentials['password'].values[0]

# %%
host="localhost"  # your host
user=user # username
passwd=pw  # password
db="FNL" # name of the database
connect_string = 'mysql+pymysql://%(user)s:%(pw)s@%(host)s:3306/%(db)s'% {"user": user, "pw": pw, "host": host, "db": db}
sql_engine = sql.create_engine(connect_string)

# %%
def read(sql_engine, table, limit=3):
    """
    Reads last limit entries from table table and returns a dataframe
    """
    query = f"SELECT * FROM {table} ORDER BY id DESC LIMIT {limit}"
    df = pd.read_sql(query, sql_engine)

    return df

def truncate_table(tableName):
    """
    Deletes everything in the table and resets the increment.
    """
    sql_engine.execute(f"DELETE FROM {tableName};")
    sql_engine.execute(f"ALTER TABLE {tableName} AUTO_INCREMENT = 1;")
#     sql_engine.execute(f"SET FOREIGN_KEY_CHECKS = 0;TRUNCATE {tableName};SET FOREIGN_KEY_CHECKS = 1;", multi=True)

def insert_experiment(sql_engine, date, comment, verbose=False):
    """
    Insert an entry into the experiment table.
    """
    table = 'experiment'
    query = f"""INSERT INTO {table} (date, comment) VALUES (\"{date}\", "{comment}\");"""
    if verbose: print(query)
        
    sql_engine.execute(sql.text(query))
    
def insert_tag(sql_engine, tag_name, verbose=False):
    """
    Insert an entry into the tag table.
    """
    table = 'tag'
    query = f"""INSERT INTO {table} (tag_name) VALUES (\"{tag_name}\");"""
    if verbose: print(query)    
    sql_engine.execute(sql.text(query))
    
def insert_user(sql_engine, user_name, comment, verbose=False):
    """
    Insert an entry into the tag table.
    """
    table = 'user'
    query = f"""INSERT INTO {table} (name, comment) VALUES (\"{user_name}\", \"{comment}\");"""
    if verbose: print(query)    
    sql_engine.execute(sql.text(query))

# %% [markdown]
# # Experiment table

# %%
date = datetime.datetime.now().replace(microsecond=0).strftime('%Y-%m-%d %H:%M:%S')
comment = 'Test case 5'
insert_experiment(sql_engine, date, comment)
# str(comment)
# Out:
# INSERT INTO experiment (date, comment) VALUES ("2020-08-03 16:55:00", "Test case 5");

# %%
read(sql_engine, 'experiment', limit=100)
# Out:
#     id                date                comment
# 0   21 2020-08-10 14:43:31              aaa123123
# 1   20 2020-08-10 14:41:40                qqqqqqf
# 2   19 2020-08-10 14:40:09                   qqqq
# 3   18 2020-08-10 14:36:27                     kk
# 4   17 2020-08-10 12:38:46  emitting and security
# 5   16 2020-08-10 11:52:57                   test
# 6   15 2020-08-10 11:51:43                   test
# 7   14 2020-08-10 11:50:30                  heute
# 8   13 2020-08-07 21:24:43                   asdf
# 9   12 2020-08-07 21:23:20                   asdf
# 10  11 2020-08-07 21:20:47                   test
# 11  10 2020-08-07 21:00:27                    sdf
# 12   9 2020-08-07 20:59:59                    aaa
# 13   8 2020-08-07 20:54:41
# 14   7 2020-08-07 20:53:43                  test3
# 15   6 2020-08-07 20:53:28                   test
# 16   5 2020-08-03 16:55:00            Test case 5
# 17   4 2020-08-03 16:54:58            Test case 4
# 18   3 2020-08-03 16:54:50            Test case 3
# 19   2 2020-08-03 16:54:39            Test case 2
# 20   1 2020-08-03 16:51:52            Test case 1

# %%
connection = sql_engine.raw_connection()
cur = connection.cursor()
try:
    query = f"""INSERT INTO experiment (date, comment) VALUES (\"2020-08-10 17:00:00\", \"just a test\");"""
    cur.execute(query)
    
    query = f"""INSERT INTO experient (date, comment) VALUES (\"2020-08-10 17:01:00\", \"just another test\");"""
    cur.execute(query)
    
    connection.commit()     
except Exception as e:
    connection.rollback()
    raise e

# %%
read(sql_engine, 'experiment', limit=100)
# Out:
#     id                date                comment
# 0   27 2020-08-10 16:01:00      just another test
# 1   26 2020-08-10 16:00:00            just a test
# 2   25 2020-08-10 15:01:00      just another test
# 3   24 2020-08-10 15:00:00            just a test
# 4   23 2020-08-10 15:00:00            just a test
# 5   22 2020-08-10 15:00:00            just a test
# 6   21 2020-08-10 14:43:31              aaa123123
# 7   20 2020-08-10 14:41:40                qqqqqqf
# 8   19 2020-08-10 14:40:09                   qqqq
# 9   18 2020-08-10 14:36:27                     kk
# 10  17 2020-08-10 12:38:46  emitting and security
# 11  16 2020-08-10 11:52:57                   test
# 12  15 2020-08-10 11:51:43                   test
# 13  14 2020-08-10 11:50:30                  heute
# 14  13 2020-08-07 21:24:43                   asdf
# 15  12 2020-08-07 21:23:20                   asdf
# 16  11 2020-08-07 21:20:47                   test
# 17  10 2020-08-07 21:00:27                    sdf
# 18   9 2020-08-07 20:59:59                    aaa
# 19   8 2020-08-07 20:54:41
# 20   7 2020-08-07 20:53:43                  test3
# 21   6 2020-08-07 20:53:28                   test
# 22   5 2020-08-03 16:55:00            Test case 5
# 23   4 2020-08-03 16:54:58            Test case 4
# 24   3 2020-08-03 16:54:50            Test case 3
# 25   2 2020-08-03 16:54:39            Test case 2
# 26   1 2020-08-03 16:51:52            Test case 1

# %%
df = read(sql_engine, 'experiment', limit=100)

# %%
df['date'].dt.strftime('%Y-%m-%d')
# Out:
# 0    2020-08-03
# 1    2020-08-03
# 2    2020-08-03
# 3    2020-08-03
# 4    2020-08-03
# Name: date, dtype: object

# %%
query = f"SELECT * FROM experiment WHERE date BETWEEN \"2020-08-03 00:00:00\" AND \"2020-08-03 23:59:00\";"
df = pd.read_sql(query, sql_engine)
df
# Out:
#    id                date      comment
# 0   1 2020-08-03 16:51:52  Test case 1
# 1   2 2020-08-03 16:54:39  Test case 2
# 2   3 2020-08-03 16:54:50  Test case 3
# 3   4 2020-08-03 16:54:58  Test case 4
# 4   5 2020-08-03 16:55:00  Test case 5

# %%
id_to_delete_after = 17
sql_engine.execute(f"DELETE FROM experiment_tags WHERE experiment_id >= \"{id_to_delete_after}\";")
sql_engine.execute(f"DELETE FROM experiment_users WHERE experiment_id >= \"{id_to_delete_after}\";")
sql_engine.execute(f"DELETE FROM experiment WHERE id >= \"{id_to_delete_after}\";")
sql_engine.execute(f"ALTER TABLE experiment AUTO_INCREMENT = {id_to_delete_after};")

# %% [markdown]
# # Tags table

# %%
tag_name = 'test'
insert_tag(sql_engine, tag_name, verbose=True)
# Out:
# INSERT INTO tag (tag_name) VALUES ("test");

# %%
read(sql_engine, 'tag', limit=100)
# Out:
#    id                        tag_name
# 0   6                 external guests
# 1   5  emitting spot size measurement
# 2   4            detector calibration
# 3   3                  security audit
# 4   2             performance testing
# 5   1                     maintenance

# %%
sql_engine.execute(f"DELETE FROM tag WHERE id = 7;")
sql_engine.execute(f"ALTER TABLE tag AUTO_INCREMENT = 6;")

# %% [markdown]
# # Users table

# %%
user_name = 'Benoit Soublette'
comment = 'BS41'
insert_user(sql_engine, user_name, comment, verbose=True)
# Out:
# INSERT INTO user (name, comment) VALUES ("Benoit Soublette", "BS41");

# %%
read(sql_engine, 'user', limit=100)
# Out:
#    id        name                          comment
# 0   4  TestUser10  What happens\nif I press enter?
# 1   3      Benoit                          is gone
# 2   2       Test1              I am just a test <p
# 3   1       Heiko                             KH41

# %%
sql_engine.execute("UPDATE user SET name=\"Heiko\" WHERE id=1")

# %%
query = f"SELECT experiment.id FROM experiment ORDER BY id DESC LIMIT 1;"
df = pd.read_sql(query, sql_engine)
df
# Out:
#    id
# 0  13

# %%
query = f"SELECT * FROM experiment_users ORDER BY experiment_id DESC limit 5;"
df = pd.read_sql(query, sql_engine)
df
# Out:
#    id  experiment_id  user_id
# 0  51             29        1
# 1  19             21        4
# 2  18             21        2
# 3  17             20        2
# 4  16             19        2

# %%
query = f"SELECT * FROM experiment_tags ORDER BY experiment_id DESC limit 5;"
df = pd.read_sql(query, sql_engine)
df
# Out:
#    id  experiment_id  tag_id
# 0  33             29       1
# 1   8             21       4
# 2  10             21       1
# 3   9             21       5
# 4  11             21       6

# %%
read(sql_engine, 'tag', limit=100)
# Out:
#    id                        tag_name
# 0   6                 external guests
# 1   5  emitting spot size measurement
# 2   4            detector calibration
# 3   3                  security audit
# 4   2             performance testing
# 5   1                     maintenance

# %%
sql_engine.execute(f"DELETE FROM tag WHERE id = 7;")

# %%
query = f"SELECT * FROM experiment_tags;"
df = pd.read_sql(query, sql_engine)
df
# Out:
#    id  experiment_id  tag_id
# 0   1             16       2
# 1   2             16       1

# %%
query = f"SELECT \
experiment.id as experiment_id, \
experiment.comment as comment, \
experiment_tags.tag_id as tag_id, \
tag.tag_name as tag_name, \
user.name as user_name \
FROM experiment \
LEFT JOIN experiment_tags \
ON experiment.id = experiment_tags.experiment_id \
LEFT JOIN experiment_users \
ON experiment.id = experiment_users.experiment_id \
LEFT JOIN tag \
ON tag_id = tag.id \
LEFT JOIN user \
ON user_id = user.id \
WHERE experiment.id = \"3\";"
df = pd.read_sql(query, sql_engine)
df
# Out:
#    experiment_id      comment tag_id tag_name user_name
# 0              3  Test case 3   None     None      None

# %%
import re
s = "abc \n \t \t\t \t \nefg"
s = re.sub(r'[\t]', '', s)
s
# Out:
# 'abc \n    \nefg'

# %%
query = f"SELECT \
experiment.id as experiment_id, \
experiment.comment as comment, \
experiment_tags.tag_id as tag_id \
FROM experiment \
LEFT JOIN experiment_tags \
ON experiment.id = experiment_tags.experiment_id WHERE experiment.id = 4;"
df = pd.read_sql(query, sql_engine)
df
# Out:
#    experiment_id      comment tag_id
# 0              4  Test case 4   None

# %%
df['user_name'].unique().tolist()
# Out:
# [None]

# %%
name = 'Heiko'
query = f"SELECT * FROM user WHERE name =\"{name}\";"
df = pd.read_sql(query, sql_engine)
df['id'].values[0]
# Out:
# 1

# %%
sql_engine.execute("INSERT INTO experiment_users (experiment_id, user_id) VALUES ((SELECT experiment.id FROM experiment ORDER BY id DESC LIMIT 1), 1)")

# %%
df = pd.read_sql('select * from information_schema.columns', sql_engine)
df
# Out:
#      TABLE_CATALOG        TABLE_SCHEMA                 TABLE_NAME  \
# 0              def  information_schema             CHARACTER_SETS
# 1              def  information_schema             CHARACTER_SETS
# 2              def  information_schema             CHARACTER_SETS
# 3              def  information_schema             CHARACTER_SETS
# 4              def  information_schema                 COLLATIONS
# ...            ...                 ...                        ...
# 3187           def                 sys  x$waits_global_by_latency
# 3188           def                 sys  x$waits_global_by_latency
# 3189           def                 sys  x$waits_global_by_latency
# 3190           def                 sys  x$waits_global_by_latency
# 3191           def                 sys  x$waits_global_by_latency
#
#                COLUMN_NAME  ORDINAL_POSITION COLUMN_DEFAULT IS_NULLABLE  \
# 0       CHARACTER_SET_NAME                 1                         NO
# 1     DEFAULT_COLLATE_NAME                 2                         NO
# 2              DESCRIPTION                 3                         NO
# 3                   MAXLEN                 4              0          NO
# 4           COLLATION_NAME                 1                         NO
# ...                    ...               ...            ...         ...
# 3187                events                 1           None          NO
# 3188                 total                 2           None          NO
# 3189         total_latency                 3           None          NO
# 3190           avg_latency                 4           None          NO
# 3191           max_latency                 5           None          NO
#
#      DATA_TYPE  CHARACTER_MAXIMUM_LENGTH  CHARACTER_OCTET_LENGTH  ...  \
# 0      varchar                      32.0                    96.0  ...
# 1      varchar                      32.0                    96.0  ...
# 2      varchar                      60.0                   180.0  ...
# 3       bigint                       NaN                     NaN  ...
# 4      varchar                      32.0                    96.0  ...
# ...        ...                       ...                     ...  ...
# 3187   varchar                     128.0                   384.0  ...
# 3188    bigint                       NaN                     NaN  ...
# 3189    bigint                       NaN                     NaN  ...
# 3190    bigint                       NaN                     NaN  ...
# 3191    bigint                       NaN                     NaN  ...
#
#       NUMERIC_SCALE  DATETIME_PRECISION  CHARACTER_SET_NAME   COLLATION_NAME  \
# 0               NaN                 NaN                utf8  utf8_general_ci
# 1               NaN                 NaN                utf8  utf8_general_ci
# 2               NaN                 NaN                utf8  utf8_general_ci
# 3               0.0                 NaN                None             None
# 4               NaN                 NaN                utf8  utf8_general_ci
# ...             ...                 ...                 ...              ...
# 3187            NaN                 NaN                utf8  utf8_general_ci
# 3188            0.0                 NaN                None             None
# 3189            0.0                 NaN                None             None
# 3190            0.0                 NaN                None             None
# 3191            0.0                 NaN                None             None
#
#               COLUMN_TYPE COLUMN_KEY EXTRA                       PRIVILEGES  \
# 0             varchar(32)                                            select
# 1             varchar(32)                                            select
# 2             varchar(60)                                            select
# 3               bigint(3)                                            select
# 4             varchar(32)                                            select
# ...                   ...        ...   ...                              ...
# 3187         varchar(128)                   select,insert,update,references
# 3188  bigint(20) unsigned                   select,insert,update,references
# 3189  bigint(20) unsigned                   select,insert,update,references
# 3190  bigint(20) unsigned                   select,insert,update,references
# 3191  bigint(20) unsigned                   select,insert,update,references
#
#      COLUMN_COMMENT GENERATION_EXPRESSION
# 0
# 1
# 2
# 3
# 4
# ...             ...                   ...
# 3187
# 3188
# 3189
# 3190
# 3191
#
# [3192 rows x 21 columns]

# %%
df[ df['TABLE_NAME'] == 'experiment' ]
# Out:
#     TABLE_CATALOG TABLE_SCHEMA  TABLE_NAME COLUMN_NAME  ORDINAL_POSITION  \
# 606           def          FNL  experiment          id                 1
# 607           def          FNL  experiment        date                 2
# 608           def          FNL  experiment     comment                 3
#
#         COLUMN_DEFAULT IS_NULLABLE  DATA_TYPE  CHARACTER_MAXIMUM_LENGTH  \
# 606               None          NO        int                       NaN
# 607  CURRENT_TIMESTAMP          NO  timestamp                       NaN
# 608               None         YES       text                   65535.0
#
#      CHARACTER_OCTET_LENGTH  ...  NUMERIC_SCALE  DATETIME_PRECISION  \
# 606                     NaN  ...            0.0                 NaN
# 607                     NaN  ...            NaN                 0.0
# 608                 65535.0  ...            NaN                 NaN
#
#      CHARACTER_SET_NAME     COLLATION_NAME COLUMN_TYPE COLUMN_KEY  \
# 606                None               None     int(11)        PRI
# 607                None               None   timestamp
# 608              latin1  latin1_swedish_ci        text
#
#               EXTRA                       PRIVILEGES COLUMN_COMMENT  \
# 606  auto_increment  select,insert,update,references
# 607                  select,insert,update,references
# 608                  select,insert,update,references
#
#     GENERATION_EXPRESSION
# 606
# 607
# 608
#
# [3 rows x 21 columns]

# %%
is_same = 0
if not is_same:
    print(1)
# Out:
# 1
